# %%
import timeit
from Event_Planner_Bruteforce import event_planner_brute_force
from Event_Planner_Clever import event_planner_itterative_search

#Name, Time, Cost, Fun_Value
Event_List_1 = [ 
    [[1],["Campus-Tour"],[2,20,50]],
    [[2],["Game-Night"],[3,80,120]],
    [[3],["Museum-Trip"],[4,100,150]],
    [[4],["Pizza-Workshop"],[2,60,100]],
    [[5],["Hiking"],[5,30,140]],
]

#Name, Time, Cost, Fun_Value
Event_List_2 = [
    [[1],["Welcome-BBQ"],[3,50,80]],
    [[2],["Karaoke-Night"],[2,40,70]],
    [[3],["Film-Screening"],[3,30,90]],
    [[4],["Sports-Tournament"],[4,60,110]],
    [[5],["Art-Workshop"],[2,70,95]],
    [[6],["Pub-Quiz"],[2,25,60]],
    [[7],["Bowling"],[3,80,100]],
    [[8],["Laser-Tag"],[2,90,130]],
    [[9],["Cooking-Class"],[3,75,105]],
    [[10],["Beach-Trip"],[6,120,180]],
    [[11],["Escape-Room"],[2,85,115]],
    [[12],["Open-Mic"],[2,20,50]]
]

#Name, Time, Cost, Fun_Value
Event_List_3 = [
    [[1],["Orientation-Walk"],[1,10,30]],
    [[2],["Ice-Breaker-Games"],[2,20,50]],
    [[3],["Movie-Marathon"],[5,60,140]],
    [[4],["City-Tour"],[4,80,120]],
    [[5],["Charity-Run"],[3,15,70]],
    [[6],["Trivia-Night"],[2,30,65]],
    [[7],["Wine-Tasting"],[2,100,150]],
    [[8],["Rock-Climbing"],[4,110,160]],
    [[9],["Theatre-Trip"],[4,90,130]],
    [[10],["Pottery-Class"],[3,85,125]],
    [[11],["Campus-Scavenger-Hunt"],[3,25,75]],
    [[12],["Photography-Walk"],[3,40,85]],
    [[13],["Poetry-Slam"],[2,20,55]],
    [[14],["Dance-Workshop"],[2,50,90]],
    [[15],["Baking-Competition"],[3,55,95]],
    [[16],["Outdoor-Cinema"],[4,70,115]],
    [[17],["Kayaking"],[5,130,190]],
    [[18],["Board-Game-Cafe"],[3,45,80]],
    [[19],["Comedy-Show"],[3,80,135]],
    [[20],["Volunteering-Event"],[4,10,60]],
    [[21],["Yoga-Session"],[2,35,70]],
    [[22],["Park-Picnic"],[3,30,65]],
    [[23],["Museum-Evening"],[3,75,110]],
    [[24],["Stargazing-Trip"],[4,50,100]],
    [[25],["Crafts-Fair"],[2,40,75]]
]


import timeit
import os
working_dir = os.getcwd()
new_dir = os.path.normpath(os.getcwd() + os.sep + os.pardir)
os.chdir(new_dir)
import_module = """
from Event_Planner_Bruteforce import event_planner_brute_force
from Event_Planner_Clever import event_planner_itterative_search

#Name, Time, Cost, Fun_Value
Event_List_1 = [ 
    [[1],["Campus-Tour"],[2,20,50]],
    [[2],["Game-Night"],[3,80,120]],
    [[3],["Museum-Trip"],[4,100,150]],
    [[4],["Pizza-Workshop"],[2,60,100]],
    [[5],["Hiking"],[5,30,140]],
]

#Name, Time, Cost, Fun_Value
Event_List_2 = [
    [[1],["Welcome-BBQ"],[3,50,80]],
    [[2],["Karaoke-Night"],[2,40,70]],
    [[3],["Film-Screening"],[3,30,90]],
    [[4],["Sports-Tournament"],[4,60,110]],
    [[5],["Art-Workshop"],[2,70,95]],
    [[6],["Pub-Quiz"],[2,25,60]],
    [[7],["Bowling"],[3,80,100]],
    [[8],["Laser-Tag"],[2,90,130]],
    [[9],["Cooking-Class"],[3,75,105]],
    [[10],["Beach-Trip"],[6,120,180]],
    [[11],["Escape-Room"],[2,85,115]],
    [[12],["Open-Mic"],[2,20,50]]
]

#Name, Time, Cost, Fun_Value
Event_List_3 = [
    [[1],["Orientation-Walk"],[1,10,30]],
    [[2],["Ice-Breaker-Games"],[2,20,50]],
    [[3],["Movie-Marathon"],[5,60,140]],
    [[4],["City-Tour"],[4,80,120]],
    [[5],["Charity-Run"],[3,15,70]],
    [[6],["Trivia-Night"],[2,30,65]],
    [[7],["Wine-Tasting"],[2,100,150]],
    [[8],["Rock-Climbing"],[4,110,160]],
    [[9],["Theatre-Trip"],[4,90,130]],
    [[10],["Pottery-Class"],[3,85,125]],
    [[11],["Campus-Scavenger-Hunt"],[3,25,75]],
    [[12],["Photography-Walk"],[3,40,85]],
    [[13],["Poetry-Slam"],[2,20,55]],
    [[14],["Dance-Workshop"],[2,50,90]],
    [[15],["Baking-Competition"],[3,55,95]],
    [[16],["Outdoor-Cinema"],[4,70,115]],
    [[17],["Kayaking"],[5,130,190]],
    [[18],["Board-Game-Cafe"],[3,45,80]],
    [[19],["Comedy-Show"],[3,80,135]],
    [[20],["Volunteering-Event"],[4,10,60]],
    [[21],["Yoga-Session"],[2,35,70]],
    [[22],["Park-Picnic"],[3,30,65]],
    [[23],["Museum-Evening"],[3,75,110]],
    [[24],["Stargazing-Trip"],[4,50,100]],
    [[25],["Crafts-Fair"],[2,40,75]]
]

"""

# %%
import matplotlib.pyplot as plt


codetest_0_brute = 'event_planner_brute_force(Event_List_2, 0, 0)'
codetest_0_fast = 'event_planner_itterative_search(Event_List_2, 0, 0)'
label_0 = ["(n=12, t=0, m=0)"]
for i in range(0,10):
    plt.scatter(label_0, timeit.timeit(setup=import_module, stmt=codetest_0_brute, number=1), c="blue")
    plt.scatter(label_0, timeit.timeit(setup=import_module, stmt=codetest_0_fast, number=1), c="red")

codetest_1_brute = 'event_planner_brute_force(Event_List_2, 10, 100)'
codetest_1_fast = 'event_planner_itterative_search(Event_List_2, 10, 100)'
label_1 = ["(n=12, t=10, m=100)"]
for i in range(0,10):
    plt.scatter(label_1, timeit.timeit(setup=import_module, stmt=codetest_1_brute, number=1), c="blue")
    plt.scatter(label_1, timeit.timeit(setup=import_module, stmt=codetest_1_fast, number=1), c="red")

codetest_2_brute = 'event_planner_brute_force(Event_List_2, 15, 150)'
codetest_2_fast = 'event_planner_itterative_search(Event_List_2, 15, 150)'
label_2 = ["(n=12, t=15, m=150)"]
for i in range(0,10):
    plt.scatter(label_2, timeit.timeit(setup=import_module, stmt=codetest_2_brute, number=1), c="blue")
    plt.scatter(label_2, timeit.timeit(setup=import_module, stmt=codetest_2_fast, number=1), c="red")

codetest_3_brute = 'event_planner_brute_force(Event_List_2, 20, 200)'
codetest_3_fast = 'event_planner_itterative_search(Event_List_2, 20, 200)'
label_3 = ["(n=12, t=20, m=200)"]
for i in range(0,10):
    plt.scatter(label_3, timeit.timeit(setup=import_module, stmt=codetest_3_brute, number=1), c="blue")
    plt.scatter(label_3, timeit.timeit(setup=import_module, stmt=codetest_3_fast, number=1), c="red")

codetest_4_brute = 'event_planner_brute_force(Event_List_2, 30, 300)'
codetest_4_fast = 'event_planner_itterative_search(Event_List_2, 30, 300)'
label_4 = ["(n=12, t=30, m=300)"]
for i in range(0,30):
    plt.scatter(label_4, timeit.timeit(setup=import_module, stmt=codetest_4_brute, number=1), c="blue")
    plt.scatter(label_4, timeit.timeit(setup=import_module, stmt=codetest_4_fast, number=1), c="red")

codetest_5_brute = 'event_planner_brute_force(Event_List_2, 50, 500)'
codetest_5_fast = 'event_planner_itterative_search(Event_List_2, 50, 500)'
label_5 = ["(n=12, t=50, m=500)"]
for i in range(0,30):
    plt.scatter(label_5, timeit.timeit(setup=import_module, stmt=codetest_5_brute, number=1), c="blue")
    plt.scatter(label_5, timeit.timeit(setup=import_module, stmt=codetest_5_fast, number=1), c="red")

codetest_6_brute = 'event_planner_brute_force(Event_List_2, 100, 1000)'
codetest_6_fast = 'event_planner_itterative_search(Event_List_2, 100, 1000)'
label_6 = ["(n=12, t=100, m=1000)"]
for i in range(0,50):
    plt.scatter(label_6, timeit.timeit(setup=import_module, stmt=codetest_6_brute, number=1), c="blue")
    plt.scatter(label_6, timeit.timeit(setup=import_module, stmt=codetest_6_fast, number=1), c="red")

plt.xticks(rotation=90)
plt.legend(['Brute Force','Itterative Approach'])
plt.show



#print(f"{codetest_1} took {timeit.timeit(setup=import_module, stmt=codetest_1, number=1)} seconds")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       6 label_0 = ["(n=12, t=0, m=0)"]
#       7 for i in range(0,10):
# ----> 8     plt.scatter(label_0, timeit.timeit(setup=import_module, stmt=codetest_0_brute, number=1), c="blue")
#       9     plt.scatter(label_0, timeit.timeit(setup=import_module, stmt=codetest_0_fast, number=1), c="red")
#      11 codetest_1_brute = 'event_planner_brute_force(Event_List_2, 10, 100)'
#
# File d:\anaconda3\Lib\timeit.py:237, in timeit(stmt, setup, timer, number, globals)
#     234 def timeit(stmt="pass", setup="pass", timer=default_timer,
#     235            number=default_number, globals=None):
#     236     """Convenience function to create Timer object and call timeit method."""
# --> 237     return Timer(stmt, setup, timer, globals).timeit(number)
#
# ...

# %%
def text_document_to_internal_array_translator(file_name):

    import os 

    file_path = os.path.join(r"Input_Files",file_name)
    # print(f" :- File path: {file_path}")
    try:
        if os.path.exists(file_path):

            os.chmod(file_path, 0o666)
            # print(" :- File permissions modified successfully!")
            pass
        else:
            # print(" !! File not found:", file_path)
            pass
    except PermissionError:
        print(" !! Permission denied: You don't have the necessary permissions to change the permissions of this file.")

    with open(file_path, "r", encoding="utf-8") as file:
        event_index = int(file.readline())
        time_limit, money_limit = ((file.readline().strip("\n")).split(" "))
        time_limit = int(time_limit)
        money_limit = int(money_limit)
        ID_index = 1
        event_list_translated = []
        for x in file:
            event_name, time_value, money_value, enjoyment_value = x.strip("\n").split(" ")
            event_list_translated += [[[ID_index],[event_name],[int(time_value), int(money_value), int(enjoyment_value)]]]
            ID_index += 1

    # print(" :- File content accessed successfully!")

    return time_limit, money_limit, event_list_translated

# %%
import matplotlib.pyplot as plt
import math
for i in range(15):
    #codetest_brute = f'event_planner_brute_force(None, [{i}, {i*20}, Event_List_3])'
    codetest_fast = f'event_planner_itterative_search(None, [{math.floor(i)}, {i*40}, Event_List_3])'
    #codetest_fast = f'event_planner_itterative_search("input_200.txt", [{i}, {i*20}, None])'
    label = [f"(n=200, t={i}, m={i*20}"]
    for _ in range(1):
        #plt.scatter(label, timeit.timeit(setup=import_module, stmt=codetest_brute, number=1), c="blue")
        time_value = timeit.timeit(setup=import_module, stmt=codetest_fast, number=1)
        print(f"At i = {i}, t = {time_value}")
        plt.scatter(label, time_value, c="red")

plt.xlabel("Starting Conditions")
plt.ylabel("Time to compute / seconds")
plt.xticks(rotation=90)
plt.legend(['Itterative Approach'])
plt.show
# Out:
# Length of solution list: 1 | n = 25 | max time = 0 | max budget = 0
# At i = 0, t = 0.0007363001350313425
# Length of solution list: 2 | n = 25 | max time = 1 | max budget = 40
# At i = 1, t = 0.00039499998092651367
# Length of solution list: 8 | n = 25 | max time = 2 | max budget = 80
# At i = 2, t = 0.0005702998023480177
# Length of solution list: 25 | n = 25 | max time = 3 | max budget = 120
# At i = 3, t = 0.001402800204232335
# Length of solution list: 61 | n = 25 | max time = 4 | max budget = 160
# At i = 4, t = 0.0034453999251127243
# Length of solution list: 153 | n = 25 | max time = 5 | max budget = 200
# At i = 5, t = 0.006914500147104263
# Length of solution list: 331 | n = 25 | max time = 6 | max budget = 240
# At i = 6, t = 0.01695389999076724
# Length of solution list: 701 | n = 25 | max time = 7 | max budget = 280
# At i = 7, t = 0.029211499961093068
# Length of solution list: 1404 | n = 25 | max time = 8 | max budget = 320
# At i = 8, t = 0.06021720007993281
# ...

# %%
import matplotlib.pyplot as plt
import timeit

import_module = """
from Event_Planner_Bruteforce import event_planner_brute_force
from Event_Planner_Clever import event_planner_itterative_search
"""

codetest_brute = 'event_planner_brute_force(file_name="input_small.txt")'
codetest_fast = 'event_planner_itterative_search(file_name="input_small.txt")'
label = ["input_small"]
for _ in range(10):
    plt.scatter(label, timeit.timeit(setup=import_module, stmt=codetest_brute, number=1), c="blue")
    plt.scatter(label, timeit.timeit(setup=import_module, stmt=codetest_fast, number=1), c="red")
print(f"Passed {label}")


plt.xlabel("Starting Conditions")
plt.ylabel("Time to compute / seconds")
plt.xticks(rotation=90)
plt.legend(['Brute Force','Itterative Approach'])
plt.show
# Out:
# Passed ['input_small']
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_vals = []
y_vals = []
z_vals = []
x_plus_y_vals = []
x_times_y_vals = []


_, _, event_list = text_document_to_internal_array_translator("input_10.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]

_, _, event_list = text_document_to_internal_array_translator("input_100.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]


_, _, event_list = text_document_to_internal_array_translator("input_200.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]


_, _, event_list = text_document_to_internal_array_translator("input_500.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]

_, _, event_list = text_document_to_internal_array_translator("input_1000.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]


_, _, event_list = text_document_to_internal_array_translator("input_large.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]


_, _, event_list = text_document_to_internal_array_translator("input_medium.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]


_, _, event_list = text_document_to_internal_array_translator("input_small.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]

# %%
import matplotlib.pyplot as plt
import random

fig = plt.figure(figsize=(8, 8))
"""
x_vals = []
y_vals = []
z_vals = []
x_plus_y_vals = []
x_times_y_vals = []

_, _, event_list = text_document_to_internal_array_translator("input_large.txt")
for i in event_list:
    x_vals += [i[2][0]]
    x_plus_y_vals += [i[2][0]+i[2][1]]
    x_times_y_vals += [i[2][0]*i[2][1]]
    y_vals += [i[2][1]]
    z_vals += [i[2][2]]
"""

print(min(x_vals))
print(max(x_vals))
print(min(y_vals))
print(max(y_vals))
print(min(z_vals))
print(max(z_vals))

import random
length = 7
x_base = list(range(1,200))
t_base = []
m_base = []
e_base = []
m_times_t_base = []
m_plus_t_base = []

for _ in range(1,1001):
    t_base_temp = random.randint(1,7)
    m_base_temp = random.randint(10,151)
    e_base += [int(2*(t_base_temp*t_base_temp)+10+(m_base_temp)+0.25*random.randint(-m_base_temp, m_base_temp))]
    m_times_t_base += [t_base_temp*m_base_temp]
    m_plus_t_base += [t_base_temp+m_base_temp]
    t_base += [t_base_temp]
    m_base += [m_base_temp]

y_base = []
z_base = []
y_log_base = []
y_root_base = []
y_linear_base = []
y_poly_base = []
from math import log, sqrt
for i in x_base:
    z_base += [20*i]
    y_base += [40*i]
    y_log_base += [log(i)]
    y_poly_base += [(2*(i*i))+100]
    y_linear_base += [(0.75*i)+50]
    y_root_base += [8*sqrt(abs(i))]

# m to e | y = 0.75m + 50
# t to e | y = 2t^2 + 100
# m and t to e | 



#plt.plot(x_base, y_root_base, linewidth=5)

plt.scatter(x_times_y_vals, z_vals, cmap='plasma', c=x_plus_y_vals, s=15)
plt.scatter(m_times_t_base, e_base, cmap='viridis', c='blue', s=15)
plt.legend(["Actual points","predicted points"])
plt.xlabel("Time cost x Money cost / [t*m]")
plt.ylabel("Enjoyment Value / [e]")
plt.title(["Relationship between time and money and enjoyment"])
plt.show()
# Out:
# 1
# 6
# 10
# 150
# 30
# 248
# C:\Users\Dylan\AppData\Local\Temp\ipykernel_12280\3128321704.py:70: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(m_times_t_base, e_base, cmap='viridis', c='blue', s=15)
